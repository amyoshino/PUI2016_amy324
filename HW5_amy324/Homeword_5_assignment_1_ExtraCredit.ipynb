# %% [markdown]
# ## Assignment 1 - Extra Credit
#
# ### Test whether a gaussian model N($\mu$, $\sigma$) for the age distribution of citibike drivers is a sensible model, or if you can find a better fit with another distribution.
#
# - Use 2 tests: KS, AD, KL, chisq (even though we have not talked about it in detail yet) to do this.
#
# - Test at the Normal and a least one other distributions (e.g. Poisson, or Binomial, or Chisq, Lognormal.......)
#
# Extra credit: Divide your sample geographically: by Borrow + split Manhattan in an Uptown and a Downtown sample (use your discretion to do so, but ZIP code is a good idea) and see if you notice any differences in how the age distribution can be modeled.

# %% [markdown]
# ### I made this code on local computer as urllib dont work on compute environment. I also developed this notebook using python 3

# %%
import pylab as pl
import pandas as pd
import numpy as np
import os
import scipy.stats
import json
import urllib.request as ulr

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datestring = '201503'

# %%
df = pd.read_csv(datestring + '-citibike-tripdata.csv')
df.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           669  3/1/2015 0:00  3/1/2015 0:11               164
# 1           750  3/1/2015 0:01  3/1/2015 0:14               258
# 2           663  3/1/2015 0:01  3/1/2015 0:12               497
# 3           480  3/1/2015 0:02  3/1/2015 0:10               470
# 4          1258  3/1/2015 0:02  3/1/2015 0:23               345
#
#             start station name  start station latitude  \
# 0              E 47 St & 2 Ave               40.753231
# 1  DeKalb Ave & Vanderbilt Ave               40.689407
# 2           E 17 St & Broadway               40.737050
# 3              W 20 St & 8 Ave               40.743453
# 4              W 13 St & 6 Ave               40.736494
#
#    start station longitude  end station id            end station name  \
# 0               -73.970325             477             W 41 St & 8 Ave
# 1               -73.968855             436    Hancock St & Bedford Ave
# ...

# %%
# df is the dataframe where the content of the csv file is stored
df['date'] = pd.to_datetime(df['starttime'])
# note that with dataframes I can refer to variables as dictionary keys, 
# i.e. df['starttime'] or as attributes: df.starttime. 
df.head(3)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           669  3/1/2015 0:00  3/1/2015 0:11               164
# 1           750  3/1/2015 0:01  3/1/2015 0:14               258
# 2           663  3/1/2015 0:01  3/1/2015 0:12               497
#
#             start station name  start station latitude  \
# 0              E 47 St & 2 Ave               40.753231
# 1  DeKalb Ave & Vanderbilt Ave               40.689407
# 2           E 17 St & Broadway               40.737050
#
#    start station longitude  end station id          end station name  \
# 0               -73.970325             477           W 41 St & 8 Ave
# 1               -73.968855             436  Hancock St & Bedford Ave
# 2               -73.990093             477           W 41 St & 8 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.756405             -73.990026   21409  Subscriber
# ...

# %%
df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender', 'date'],
#       dtype='object')

# %%
#df is the dataframe where the content of the csv file is stored
df['age'] = 2015 - df['birth year'][(df['usertype'] == 'Subscriber')]
df['ageM'] = 2015 - df['birth year'][(df['usertype'] == 'Subscriber') & (df['gender'] == 1)]
df['ageF'] = 2015 - df['birth year'][(df['usertype'] == 'Subscriber') & (df['gender'] == 2)]

# %%
# dropping NaN values
df['age'].dropna(inplace= True)
df['ageM'].dropna(inplace= True)
df['ageF'].dropna(inplace= True)

# %%
df.head(3)
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           669  3/1/2015 0:00  3/1/2015 0:11               164
# 1           750  3/1/2015 0:01  3/1/2015 0:14               258
# 2           663  3/1/2015 0:01  3/1/2015 0:12               497
#
#             start station name  start station latitude  \
# 0              E 47 St & 2 Ave               40.753231
# 1  DeKalb Ave & Vanderbilt Ave               40.689407
# 2           E 17 St & Broadway               40.737050
#
#    start station longitude  end station id          end station name  \
# 0               -73.970325             477           W 41 St & 8 Ave
# 1               -73.968855             436  Hancock St & Bedford Ave
# 2               -73.990093             477           W 41 St & 8 Ave
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.756405             -73.990026   21409  Subscriber
# ...

# %%
import urllib.request as ulr

# %%
    url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng=' + str(df['start station latitude'][0]) + ',' \
    + str(df['start station longitude'][0]) + '&key=AIzaSyAW3x05Zr8JEQBRqnnXaB3G27RQSfy0Bk4'

# %%
url
# Out:
# 'https://maps.googleapis.com/maps/api/geocode/json?latlng=40.75323098,-73.97032517&key=AIzaSyAW3x05Zr8JEQBRqnnXaB3G27RQSfy0Bk4'

# %%
borough = []

# %%
borough
# Out:
# []

# %%
for i in range(0, len(df)):
    url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng=' + str(df['start station latitude'][i]) + ',' \
    + str(df['start station longitude'][i]) + '&key=AIzaSyAW3x05Zr8JEQBRqnnXaB3G27RQSfy0Bk4'
    response = ulr.urlopen(url)
    data = response.read().decode("utf-8")
    data = json.loads(data)
    borough.append(data['results'][0]['address_components'][3]['long_name'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-79-09334bbabf83> in <module>()
#       4     data = response.read().decode("utf-8")
#       5     data = json.loads(data)
# ----> 6     borough.append(data['results'][0]['address_components'][3]['long_name'])
#
# IndexError: list index out of range

# %%
borough
# Out:
# ['Manhattan',
#  'Brooklyn',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'New York',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'New York',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
#  'Manhattan',
# ...

# %%
df['borough'] = pd.DataFrame(borough)

# %%
df
# Out:
#         tripduration        starttime         stoptime  start station id  \
# 0                669    3/1/2015 0:00    3/1/2015 0:11               164
# 1                750    3/1/2015 0:01    3/1/2015 0:14               258
# 2                663    3/1/2015 0:01    3/1/2015 0:12               497
# 3                480    3/1/2015 0:02    3/1/2015 0:10               470
# 4               1258    3/1/2015 0:02    3/1/2015 0:23               345
# 5                363    3/1/2015 0:03    3/1/2015 0:09               380
# 6                187    3/1/2015 0:04    3/1/2015 0:07               470
# 7                501    3/1/2015 0:04    3/1/2015 0:13               168
# 8                606    3/1/2015 0:05    3/1/2015 0:15               345
# 9               1488    3/1/2015 0:05    3/1/2015 0:30               499
# 10              1303    3/1/2015 0:05    3/1/2015 0:27              2017
# 11               400    3/1/2015 0:06    3/1/2015 0:13               173
# ...

# %%
len(df.borough)
# Out:
# 341826

# %%
df['age_manhattan'] = 2015 - df['birth year'][(df['usertype'] == 'Subscriber')][(df['borough'] == 'Manhattan')]

# %%
df['age_manhattan'].dropna(inplace= True)

# %% [markdown]
# #### KS Test to Manhattan age distribution (Normal and Poisson)

# %%
scipy.stats.kstest(df['age_manhattan'], 'norm', args=(df.age_manhattan.mean(), df.age_manhattan.std()))
# Out:
# KstestResult(statistic=0.10936608089452893, pvalue=0.0)

# %% [markdown]
# - Null Hypothesis: the two distributions are identical (the distribution is normal)
# - As the p-value (0.00) is < than the desired significance level (let's use 0.05), we can reject the Null Hypothesis. So the age of Citibike customers are not distributed as a normal distribution.

# %%
scipy.stats.kstest(df['age_manhattan'], 'poisson', args=(df.age_manhattan.mean(), df.age_manhattan.std()))
# Out:
# KstestResult(statistic=0.5519779740434767, pvalue=0.0)

# %% [markdown]
# - Null Hypothesis: the two distributions are identical (the distribution is poisson)
# -  As the p-value (0.00) is < than the desired significance level (let's use 0.05), we can reject the Null Hypothesis. So the age of Citibike customers are not distributed as a poisson distribution.

# %% [markdown]
# #### AD Test to Manhattan age distribution (Normal)

# %%
scipy.stats.anderson(df['age_manhattan'], 'norm')
# Out:
# AndersonResult(statistic=30.596454352118144, critical_values=array([ 0.575,  0.655,  0.786,  0.916,  1.09 ]), significance_level=array([ 15. ,  10. ,   5. ,   2.5,   1. ]))

# %% [markdown]
# - null hypothesis: a sample is drawn from a population that follows a particular distribution (in this case, normal)
# - As we see, Statistic >> 0.786 (critical value for significance 0.05), so we reject the null hypothesis, i.e. sample is not drawn from a population that follows normal distribution.
